# %%
from stock_data import  get_hs300_components,get_stock_name,get_stock_data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

hs300 = get_hs300_components()
start_date = '20211115'
end_date = '20241115'
hs300_code = hs300['品种代码']
hs300_name = hs300['品种名称']

# %%
hs300_data = {}
for code in hs300_code:
    hs300_data[code] = get_stock_data(code,start_date,end_date)
    print('获取{} {}数据'.format(code,get_stock_name(code)))
# Out:
# 获取600415 小商品城数据
# 获取300418 昆仑万维数据
# 获取600161 天坛生物数据
# 获取688082 盛美上海数据
# 获取688009 中国通号数据
# 获取300442 润泽科技数据
# 获取603296 华勤技术数据
# 获取001965 招商公路数据
# 获取600027 华电国际数据
# 获取600026 中远海能数据
# 获取300832 新产业数据
# 获取000807 云铝股份数据
# 获取600515 海南机场数据
# 获取600372 中航机载数据
# 获取601916 浙商银行数据
# 获取002603 以岭药业数据
# 获取600489 中金黄金数据
# 获取000999 华润三九数据
# 获取688041 海光信息数据
# 获取600023 浙能电力数据
# 获取600938 中国海油数据
# 获取688271 联影医疗数据
# 获取300308 中际旭创数据
# 获取301269 华大九天数据
# 获取688256 寒武纪-U数据
# 获取601059 信达证券数据
# 获取688223 晶科能源数据
# 获取601607 上海医药数据
# 获取601699 潞安环能数据
# 获取000617 中油资本数据
# 获取600875 东方电气数据
# 获取000983 山西焦煤数据
# 获取601872 招商轮船数据
# 获取600732 爱旭股份数据
# 获取688187 时代电气数据
# 获取000733 振华科技数据
# 获取688303 大全能源数据
# 获取605117 德业股份数据
# 获取600039 四川路桥数据
# 获取600674 川投能源数据
# 获取601689 拓普集团数据
# 获取000733 振华科技数据
# 获取600039 四川路桥数据
# 获取600233 圆通速递数据
# 获取300223 北京君正数据
# 获取600460 士兰微数据
# 获取300957 贝泰妮数据
# 获取002074 国轩高科数据
# 获取001289 龙源电力数据
# 获取002648 卫星化学数据
# 获取600941 中国移动数据
# 获取300496 中科创达数据
# 获取601117 中国化学数据
# 获取002920 德赛西威数据
# 获取300919 中伟股份数据
# ...

# %%
hs300_data['000001']
# Out:
#              open  close   high    low   volume  turnover
# datetime
# 2021-11-15  18.35  18.43  18.63  18.20   655090      0.34
# 2021-11-16  18.36  18.22  18.54  18.17   601110      0.31
# 2021-11-17  18.15  18.11  18.30  17.98   664640      0.34
# 2021-11-18  18.09  17.80  18.12  17.73   799844      0.41
# 2021-11-19  17.80  18.15  18.24  17.70   786372      0.41
# ...           ...    ...    ...    ...      ...       ...
# 2024-11-11  11.63  11.60  11.68  11.47  1486952      0.77
# 2024-11-12  11.58  11.54  11.84  11.51  1717663      0.89
# 2024-11-13  11.50  11.61  11.70  11.48  1086263      0.56
# 2024-11-14  11.59  11.54  11.70  11.53  1159783      0.60
# 2024-11-15  11.50  11.44  11.61  11.42  1215784      0.63
#
# [729 rows x 6 columns]
